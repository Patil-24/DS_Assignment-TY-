# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup


my_url = 'https://www.newegg.com/Desktop-Graphics-Cards/SubCategory/ID-48?Tid=7709'
uclient = uReq(my_url)
page_html = uclient.read()
uclient.close()
page_soup = soup(page_html,"html.parser")

containers = page_soup.findAll("div", {"class":"item-container"})

file_name = "product.csv"
f = open(file_name, "w")

headers = "brand , shipping , price \n"
f.write(headers)



for container in containers:
    brand = container.a.img["title"]

    

    shipping_container = container.findAll("li", {"class":"price-ship"})
    shipping = shipping_container[0].text.strip()

    price_list = container.findAll("li", {"class":"price-current"})
    price = price_list[0].text.strip().replace("|","").replace('\r', '').replace('\n', '')


    print("brand : " + brand)
    # print("product_name : " + product_name)
    print("shipping :  " + shipping)
    print("price : " + price)
    print("_____________________________________________________________________________________________________________")


    f.write(brand.replace(",","|") + "," + shipping + "," + price.replace(",",".") + "\n")

f.close()
# Out:
# brand : ASUS ROG Strix GeForce RTX 3090 24GB GDDR6X PCI Express 4.0 SLI Support Video Card ROG-STRIX-RTX3090-O24G-GAMING
# shipping :  $9.99 Shipping
# price : $1,699.99 (12 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE GeForce RTX 3090 GAMING OC 24G Video Card, GV-N3090GAMING OC-24GD
# shipping :  $9.99 Shipping
# price : $1,599.99 (15 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Radeon RX 6900 XT GAMING OC Video Card, GV-R69XTGAMING OC-16GD
# shipping :  Free Shipping
# price : $1,049.99 (14 Offers)–
# _____________________________________________________________________________________________________________
# brand : ASUS TUF Gaming GeForce RTX 3070 Ti 8GB GDDR6X PCI Express 4.0 Video Card TUF-RTX3070TI-O8G-GAMING
# shipping :  Free Shipping
# price : $699.99 (27 Offers)–
# _____________________________________________________________________________________________________________
# brand : ASUS ROG Strix GeForce RTX 3050 8GB GDDR6 PCI Express 4.0 Video Card ROG-STRIX-RTX3050-O8G-GAMING
# shipping :  Free Shipping
# price : $429.99 (24 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE GeForce RTX 3050 GAMING OC 8G Graphics Card, 3x WINDFORCE Fans, 8GB GDDR6 128-bit GDDR6, GV-N3050GAMING OC-8GD Video Card
# shipping :  Free Shipping
# price : $349.99 (23 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE GAMING OC Radeon RX 6500 XT 4GB GDDR6 PCI Express 4.0 ATX Video Card GV-R65XTGAMING OC-4GD
# shipping :  Free Shipping
# price : $199.99 (11 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Mech Radeon RX 6500 XT 4GB GDDR6 PCI Express 4.0 Video Card RX 6500 XT MECH 2X 4G OC
# shipping :  $9.99 Shipping
# price : $204.99 (10 Offers)–
# _____________________________________________________________________________________________________________
# brand : ASRock OC Formula Radeon RX 6900 XT 16GB GDDR6 PCI Express 4.0 ATX Video Card RX6900XT OCF 16G
# shipping :  $9.99 Shipping
# price : $999.99 (3 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Radeon RX 6700 XT GAMING OC 12G Graphics Card, WINDFORCE 3X Cooling System, 12GB 192-bit GDDR6, GV-R67XTGAMING OC-12GD Video Card
# shipping :  Free Shipping
# price : $549.99 (18 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Gaming Radeon RX 6700 XT 12GB GDDR6 PCI Express 4.0 Video Card RX 6700 XT GAMING X 12G
# shipping :  $9.99 Shipping
# price : $539.99 (3 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Eagle OC GeForce RTX 3070 8GB GDDR6 PCI Express 4.0 ATX Video Card GV-N3070EAGLE OC-8GD (rev. 2.0) (LHR)
# shipping :  Free Shipping
# price : $699.99 (4 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Ventus GeForce RTX 3060 12GB GDDR6 PCI Express 4.0 Video Card RTX 3060 Ventus 2X 12G OC
# shipping :  $9.99 Shipping
# price : $429.99 (9 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
# shipping :  Free Shipping
# price : $799.99 (17 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Vision OC GeForce RTX 3070 8GB GDDR6 PCI Express 4.0 ATX Video Card GV-N3070VISION OC-8GD (rev. 2.0) (LHR)
# shipping :  $9.99 Shipping
# price : $599.99 (7 Offers)–
# _____________________________________________________________________________________________________________
# brand : EVGA GeForce RTX 3060 XC BLACK GAMING, 12G-P5-3655-KR, 12GB GDDR6, Dual-Fan
# shipping :  $9.99 Shipping
# price : $399.99 (6 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Gaming OC GeForce RTX 3070 8GB GDDR6 PCI Express 4.0 ATX Video Card GV-N3070GAMING OC-8GD (rev. 2.0) (LHR)
# shipping :  Free Shipping
# price : $599.99 (16 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Ventus GeForce RTX 3060 12GB GDDR6 PCI Express 4.0 Video Card RTX 3060 Ventus 3X 12G OC
# shipping :  $9.99 Shipping
# price : $449.99 (9 Offers)–
# _____________________________________________________________________________________________________________
# brand : XFX SPEEDSTER SWFT 210 Radeon RX 6600 8GB GDDR6 PCI Express 4.0 Video Card RX-66XL8LFDQ
# shipping :  Free Shipping
# price : $299.99 (14 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR)
# shipping :  Free Shipping
# price : $799.99 (10 Offers)–
# _____________________________________________________________________________________________________________
# brand : ASUS ROG Strix GeForce RTX 3060 12GB GDDR6 PCI Express 4.0 Video Card ROG-STRIX-RTX3060-O12G-V2-GAMING
# shipping :  Free Shipping
# price : $489.99 (18 Offers)–
# _____________________________________________________________________________________________________________
# brand : EVGA GeForce RTX 3090 Ti FTW3 ULTRA GAMING, 24G-P5-4985-KR, 24GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, Includes eLeash
# shipping :  Free Shipping
# price : $1,999.99 –
# _____________________________________________________________________________________________________________
# brand : EVGA GeForce RTX 3080 Ti FTW3 ULTRA GAMING Video Card, 12G-P5-3967-KR, 12GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
# shipping :  Free Shipping
# price : $1,219.99 (19 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Ventus GeForce RTX 3060 Ti 8GB GDDR6 PCI Express 4.0 Video Card RTX 3060 Ti VENTUS 2X 8G OCV1 LHR
# shipping :  Free Shipping
# price : $569.99 (21 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Mech Radeon RX 6700 XT 12GB GDDR6 PCI Express 4.0 Video Card RX 6700 XT MECH 2X 12G
# shipping :  $9.99 Shipping
# price : $499.99 (11 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Eagle OC GeForce RTX 3060 12GB GDDR6 PCI Express 4.0 ATX Video Card GV-N3060EAGLE OC-12GD (rev. 2.0) (LHR)
# shipping :  Free Shipping
# price : $399.99 (14 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Mech Radeon RX 6600 8GB PCI Express 4.0 Video Card RX 6600 MECH 2X 8G
# shipping :  $9.99 Shipping
# price : $349.99 (17 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Gaming GeForce RTX 3070 Ti 8GB GDDR6X PCI Express 4.0 ATX Video Card GV-N307TGAMING OC-8GD
# shipping :  Free Shipping
# price : $699.99 (24 Offers)–
# _____________________________________________________________________________________________________________
# brand : XFX SPEEDSTER MERC319 AMD Radeon RX 6900 XT LIMITED BLACK Gaming Graphics Card with 16GB GDDR6, AMD RDNA 2, RX-69XTACSD9
# shipping :  Free Shipping
# price : $899.99 (5 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Eagle GeForce RTX 3070 Ti 8GB GDDR6X PCI Express 4.0 ATX Video Card GV-N307TEAGLE OC-8GD
# shipping :  Free Shipping
# price : $699.99 (10 Offers)–
# _____________________________________________________________________________________________________________
# brand : EVGA GeForce RTX 3090 FTW3 ULTRA GAMING Video Card, 24G-P5-3987-KR, 24GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
# shipping :  Free Shipping
# price : $1,699.99 (13 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Ventus GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 VENTUS 3X PLUS 10G OC LHR
# shipping :  $9.99 Shipping
# price : $849.99 (19 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE AORUS GeForce RTX 3070 MASTER 8GB GDDR6 PCI Express 4.0 ATX Video Card GV-N3070AORUS M-8GD (rev. 2.0) (LHR)
# shipping :  Free Shipping
# price : $649.99 (21 Offers)–
# _____________________________________________________________________________________________________________
# brand : MSI Gaming Radeon RX 6900 XT 16GB GDDR6 PCI Express 4.0 Video Card RX 6900 XT Gaming X Trio 16G
# shipping :  $9.99 Shipping
# price : $899.99 (12 Offers)–
# _____________________________________________________________________________________________________________
# brand : ASUS TUF Gaming GeForce RTX 3070 V2 OC Edition 8GB GDDR6 PCI Express 4.0 Video Card TUF-RTX3070-O8G-V2-GAMING (LHR)
# shipping :  $9.99 Shipping
# price : $659.99 (16 Offers)–
# _____________________________________________________________________________________________________________
# brand : GIGABYTE Gaming OC GeForce RTX 3060 12GB GDDR6 PCI Express 4.0 ATX Video Card GV-N3060GAMING OC-12GD (rev. 2.0) (LHR)
# shipping :  $9.99 Shipping
# price : $439.99 (14 Offers)–
# _____________________________________________________________________________________________________________
